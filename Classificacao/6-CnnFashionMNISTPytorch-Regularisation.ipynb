# %% [markdown]
# # **Regularização no PyTorch**
# ### Agora, usamos alguns métodos de regularização em nossa CNN Fashion-MNIST
#
# Primeiro aprenderemos a criar um **modelo simples de rede neural convolucional** no PyTorch e a treiná-lo para **classificar imagens no conjunto de dados Fashion-MNIST**, agora **COM** o uso de qualquer método de regularização.
# 1. Importe as bibliotecas do PyTorch, defina nossos transformadores, carregue nosso conjunto de dados e visualize nossas imagens.
# 2. Crie uma CNN simples com os seguintes métodos de **regularização**:
#   - Regularização L2
#   - Aumento de dados
#   - Dropout
#   - BatchNorm
# 3. Treinamento de nossa CNN com regularização

# %%
# Import PyTorch
import torch
import PIL
import numpy as np

# We use torchvision to get our dataset and useful image transformations
import torchvision
import torchvision.transforms as transforms

# Import PyTorch's optimization libary and nn
# nn is used as the basic building block for our Network graphs
import torch.optim as optim
import torch.nn as nn

# Are we using our GPU?
print("GPU available: {}".format(torch.cuda.is_available()))
# Out:
# GPU available: True

# %%
device = 'cuda' #'cpu' if no GPU available

# %% [markdown]
# # **2. Criando uma CNN com regulamentação**
# ## **Implementando o aumento de dados**
#
# #### **Entendendo o que as nossas transformações fazem**
#
# 1. Nossas transformações são aplicadas a uma imagem ou a um lote de imagens sempre que ela é carregada.
# 2. Essas novas imagens não são salvas, elas são geradas ou “alteradas” sempre que um lote é carregado
#
# #### **NOTA**
#
# Não aplicamos as mesmas ampliações aos nossos conjuntos de dados de teste ou de validação. Portanto, mantemos funções de transformação separadas (veja abaixo) para nossos dados de treinamento e validação/teste.

# %% [markdown]
# ### Aumentos geométricos e fotométricos
# https://docs.pytorch.org/vision/main/auto_examples/transforms/plot_transforms_illustrations.html#
#
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)

# %%
data_transforms = {
    'train': transforms.Compose([
        # Observe que elas são executadas na ordem em que são chamadas aqui
        # Algumas dessas transformações retornam uma imagem colorida, por isso precisamos converter
        # a imagem de volta para tons de cinza
        
        transforms.RandomAffine(degrees = 10, translate = (0.05,0.05), shear = 5), 
        transforms.ColorJitter(hue = .05, saturation = .05),
        transforms.RandomHorizontalFlip(),
        transforms.RandomRotation(15, interpolation = PIL.Image.BILINEAR),
        transforms.Grayscale(num_output_channels = 1),
        transforms.ToTensor(),
        transforms.Normalize((0.5, ), (0.5, )),
    ]),
    'val': transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.5, ), (0.5, ))
    ])
}

# %%
# Carregar nossos dados de treino e especificar qual transformação usar ao carregar
trainset = torchvision.datasets.FashionMNIST(root='./fashion', train=True,
                                        download=True, transform=data_transforms['train'])

# Carregar nossos dados de teste e especificar qual transformação usar ao carregar
testset = torchvision.datasets.FashionMNIST(root='./fashion', train=False,
                                       download=True, transform=data_transforms['val'])

# Prepare train and test loader
trainloader = torch.utils.data.DataLoader(trainset, batch_size=32,
                                          shuffle=True, num_workers=2)

testloader = torch.utils.data.DataLoader(testset, batch_size=32,
                                         shuffle=False, num_workers=2)
# Out:
# 100%|██████████| 26.4M/26.4M [00:04<00:00, 5.49MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 58.9MB/s]
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 2.62MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 12.5MB/s]

# %% [markdown]
# ### **Adicionando Dropout**
#
# Nas redes neurais convolucionais, o dropout é comumente adicionado após as camadas CONV-RELU.
#
# Por exemplo, CONV->RELU->**DROPOUT**
#
# #### **Dropout Recommendations**
#
# Em CNNs, valores de 0,1 a 0,3 têm funcionado bem.
#
# ### **Adicionar BatchNorm**
#
# Nas CNNs, o **BatchNorm** é melhor usado entre a camada de Convolução e a camada de função de ativação (ReLU)
# Quando usado com Dropout, a ordem recomendada é:
#
# CONV_1 -> **BatchNorm** -> ReLU -> Dropout - CONV_2
#
# **NOTA** O argumento de entrada do BatchNorm é o tamanho da **saída** da camada anterior.

# %%
import torch.nn as nn
import torch.nn.functional as F

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3)
        # Adicionando BatchNorm, usando 32 como entrada, já que 32 foi a saída de nossa primeira camada de Conv.
        self.conv1_bn = nn.BatchNorm2d(32)
        self.conv2 = nn.Conv2d(32, 64, 3)
        # Adicionando o BatchNorm, usando 64 como entrada, já que 64 foi a saída de nossa primeira camada de Conv.
        self.conv2_bn = nn.BatchNorm2d(64)
        self.pool = nn.MaxPool2d(2, 2)
        self.fc1 = nn.Linear(64 * 12 * 12, 128)
        self.fc2 = nn.Linear(128, 10)
        # Definindo nossa função de dropout com uma taxa de 0,2
        # Podemos aplicar isso depois de qualquer camada, mas é mais adequado depois do ReLU
        self.dropOut = nn.Dropout(0.2)

    def forward(self, x):
        x = F.relu(self.conv1_bn(self.conv1(x)))
        x = self.dropOut(x)
        x = self.dropOut(F.relu(self.conv2_bn(self.conv2(x))))

        x = self.pool(x)
        x = x.view(-1, 64 * 12 * 12)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        return x


net = Net()
net.to(device)
# Out:
# Net(
#   (conv1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1))
#   (conv1_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#   (conv2_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=9216, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
#   (dropOut): Dropout(p=0.2, inplace=False)
# )

# %% [markdown]
# ### **Adicionando a regularização L2**
#
#
# A regularização L2 nos parâmetros/pesos do modelo é incluída diretamente na maioria dos otimizadores, incluindo o optim.SGD.
#
# Ela pode ser controlada com o parâmetro **weight_decay**, como pode ser visto na [documentação do SGD] (http://pytorch.org/docs/optim.html#torch.optim.SGD).
#
# ``weight_decay`` (**float**, opcional) - decaimento do peso *(penalidade L2) (padrão: 0)*
#
# **Bons valores de L2 variam de 0,1 a 0,0001**
#
# **NOTA:**
#
#  A regularização L1 não é incluída por padrão nos otimizadores, mas pode ser adicionada por meio da inclusão de uma perda extra nn.L1Loss nos pesos do modelo.

# %%
import torch.optim as optim

criterion = nn.CrossEntropyLoss()

optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9, weight_decay = 0.001)

# %% [markdown]
# # **3. Treinamento do nosso modelo usando métodos de regulação - aumento de dados, dropout, BatchNorm e regularização L2**

# %%
epochs = 15

epoch_log = []
loss_log = []
accuracy_log = []


for epoch in range(epochs):  
    print(f'Iniciando treino na época: {epoch+1}...')

    # Continuamos adicionando ou acumulando nossa perda após cada mini-lote em running_loss
    running_loss = 0.0

    for i, data in enumerate(trainloader, 0):
        # obtenha as entradas; os dados são uma lista de [entradas, rótulos]
        inputs, labels = data

        inputs = inputs.to(device)
        labels = labels.to(device)
        
        optimizer.zero_grad()

        # Forward -> backprop + optimize
        outputs = net(inputs) # Forward Propagation 
        loss = criterion(outputs, labels) # Obter perdas (quantificar a diferença entre os resultados e as previsões)
        loss.backward() # Propagar de volta para obter os novos gradientes para todos os nós
        optimizer.step() # Atualizar os gradientes/pesos

        # Print Training statistics - Epoch/Iterations/Loss/Accurachy
        running_loss += loss.item()
        if i % 100 == 99:    # Mostrar a Loss a cada 50 mini-batches
            correct = 0 # Contando predições certas
            total = 0 # Contando os rotulos iterados

            # Contexto no_grad
            with torch.no_grad():
                # Interando sobre o loader de teste
                for data in testloader:
                    images, labels = data
                    
                    images = images.to(device)
                    labels = labels.to(device)
                    
                    # Pegando as probabilidades das predições
                    outputs = net(images)

                     # Pegando as maiores probabilidades
                    _, predicted = torch.max(outputs.data, 1)
                    # adicionando o tamanho ou o comprimento do rotulo à variável total
                    total += labels.size(0)
                    # Mantenha um total contínuo do número de previsões feitas corretamente
                    correct += (predicted == labels).sum().item()

                accuracy = 100 * correct / total
                epoch_num = epoch + 1
                actual_loss = running_loss / 50
                print(f'Época: {epoch_num}, Mini-Batches completados: {(i+1)}, Loss: {actual_loss:.3f}, Acurácia de teste = {accuracy:.3f}%')
                running_loss = 0.0

    # Store training stats after each epoch
    epoch_log.append(epoch_num)
    loss_log.append(actual_loss)
    accuracy_log.append(accuracy)

print('Treino completado')
# Out:
# Iniciando treino na época: 1...
# Época: 1, Mini-Batches completados: 100, Loss: 2.382, Acurácia de teste = 73.460%
# Época: 1, Mini-Batches completados: 200, Loss: 1.632, Acurácia de teste = 75.970%
# Época: 1, Mini-Batches completados: 300, Loss: 1.488, Acurácia de teste = 76.590%
# Época: 1, Mini-Batches completados: 400, Loss: 1.353, Acurácia de teste = 76.730%
# Época: 1, Mini-Batches completados: 500, Loss: 1.359, Acurácia de teste = 73.400%
# Época: 1, Mini-Batches completados: 600, Loss: 1.276, Acurácia de teste = 79.400%
# Época: 1, Mini-Batches completados: 700, Loss: 1.209, Acurácia de teste = 76.470%
# Época: 1, Mini-Batches completados: 800, Loss: 1.325, Acurácia de teste = 78.390%
# Época: 1, Mini-Batches completados: 900, Loss: 1.216, Acurácia de teste = 80.170%
# Época: 1, Mini-Batches completados: 1000, Loss: 1.209, Acurácia de teste = 79.850%
# Época: 1, Mini-Batches completados: 1100, Loss: 1.160, Acurácia de teste = 79.910%
# Época: 1, Mini-Batches completados: 1200, Loss: 1.140, Acurácia de teste = 80.970%
# Época: 1, Mini-Batches completados: 1300, Loss: 1.205, Acurácia de teste = 80.750%
# Época: 1, Mini-Batches completados: 1400, Loss: 1.128, Acurácia de teste = 81.650%
# Época: 1, Mini-Batches completados: 1500, Loss: 1.064, Acurácia de teste = 80.290%
# Época: 1, Mini-Batches completados: 1600, Loss: 1.112, Acurácia de teste = 80.930%
# Época: 1, Mini-Batches completados: 1700, Loss: 1.067, Acurácia de teste = 83.580%
# Época: 1, Mini-Batches completados: 1800, Loss: 1.019, Acurácia de teste = 81.510%
# Iniciando treino na época: 2...
# Época: 2, Mini-Batches completados: 100, Loss: 1.042, Acurácia de teste = 83.870%
# Época: 2, Mini-Batches completados: 200, Loss: 0.976, Acurácia de teste = 83.240%
# Época: 2, Mini-Batches completados: 300, Loss: 0.974, Acurácia de teste = 84.010%
# Época: 2, Mini-Batches completados: 400, Loss: 1.072, Acurácia de teste = 81.590%
# Época: 2, Mini-Batches completados: 500, Loss: 1.021, Acurácia de teste = 84.620%
# Época: 2, Mini-Batches completados: 600, Loss: 0.986, Acurácia de teste = 83.970%
# Época: 2, Mini-Batches completados: 700, Loss: 1.052, Acurácia de teste = 85.040%
# Época: 2, Mini-Batches completados: 800, Loss: 0.981, Acurácia de teste = 83.460%
# Época: 2, Mini-Batches completados: 900, Loss: 1.023, Acurácia de teste = 84.450%
# Época: 2, Mini-Batches completados: 1000, Loss: 0.923, Acurácia de teste = 84.920%
# Época: 2, Mini-Batches completados: 1100, Loss: 0.992, Acurácia de teste = 83.500%
# Época: 2, Mini-Batches completados: 1200, Loss: 0.999, Acurácia de teste = 84.640%
# Época: 2, Mini-Batches completados: 1300, Loss: 0.991, Acurácia de teste = 85.230%
# Época: 2, Mini-Batches completados: 1400, Loss: 0.938, Acurácia de teste = 85.310%
# Época: 2, Mini-Batches completados: 1500, Loss: 0.949, Acurácia de teste = 85.040%
# Época: 2, Mini-Batches completados: 1600, Loss: 0.931, Acurácia de teste = 84.320%
# Época: 2, Mini-Batches completados: 1700, Loss: 0.954, Acurácia de teste = 85.540%
# Época: 2, Mini-Batches completados: 1800, Loss: 0.923, Acurácia de teste = 85.120%
# Iniciando treino na época: 3...
# Época: 3, Mini-Batches completados: 100, Loss: 0.899, Acurácia de teste = 85.020%
# Época: 3, Mini-Batches completados: 200, Loss: 0.917, Acurácia de teste = 85.660%
# Época: 3, Mini-Batches completados: 300, Loss: 0.922, Acurácia de teste = 85.850%
# Época: 3, Mini-Batches completados: 400, Loss: 0.934, Acurácia de teste = 85.570%
# Época: 3, Mini-Batches completados: 500, Loss: 0.877, Acurácia de teste = 85.230%
# Época: 3, Mini-Batches completados: 600, Loss: 0.938, Acurácia de teste = 83.610%
# Época: 3, Mini-Batches completados: 700, Loss: 0.901, Acurácia de teste = 85.350%
# Época: 3, Mini-Batches completados: 800, Loss: 0.900, Acurácia de teste = 85.250%
# Época: 3, Mini-Batches completados: 900, Loss: 0.863, Acurácia de teste = 86.510%
# Época: 3, Mini-Batches completados: 1000, Loss: 0.861, Acurácia de teste = 86.520%
# Época: 3, Mini-Batches completados: 1100, Loss: 0.871, Acurácia de teste = 85.950%
# Época: 3, Mini-Batches completados: 1200, Loss: 0.871, Acurácia de teste = 86.080%
# Época: 3, Mini-Batches completados: 1300, Loss: 0.862, Acurácia de teste = 84.470%
# Época: 3, Mini-Batches completados: 1400, Loss: 0.872, Acurácia de teste = 86.200%
# Época: 3, Mini-Batches completados: 1500, Loss: 0.843, Acurácia de teste = 85.790%
# Época: 3, Mini-Batches completados: 1600, Loss: 0.875, Acurácia de teste = 85.810%
# Época: 3, Mini-Batches completados: 1700, Loss: 0.843, Acurácia de teste = 85.920%
# Época: 3, Mini-Batches completados: 1800, Loss: 0.887, Acurácia de teste = 85.660%
# Iniciando treino na época: 4...
# Época: 4, Mini-Batches completados: 100, Loss: 0.854, Acurácia de teste = 86.530%
# Época: 4, Mini-Batches completados: 200, Loss: 0.838, Acurácia de teste = 85.620%
# Época: 4, Mini-Batches completados: 300, Loss: 0.859, Acurácia de teste = 85.920%
# Época: 4, Mini-Batches completados: 400, Loss: 0.822, Acurácia de teste = 87.200%
# Época: 4, Mini-Batches completados: 500, Loss: 0.830, Acurácia de teste = 85.770%
# Época: 4, Mini-Batches completados: 600, Loss: 0.834, Acurácia de teste = 85.730%
# Época: 4, Mini-Batches completados: 700, Loss: 0.879, Acurácia de teste = 86.480%
# Época: 4, Mini-Batches completados: 800, Loss: 0.816, Acurácia de teste = 86.990%
# Época: 4, Mini-Batches completados: 900, Loss: 0.812, Acurácia de teste = 86.530%
# Época: 4, Mini-Batches completados: 1000, Loss: 0.858, Acurácia de teste = 86.890%
# Época: 4, Mini-Batches completados: 1100, Loss: 0.897, Acurácia de teste = 86.850%
# Época: 4, Mini-Batches completados: 1200, Loss: 0.818, Acurácia de teste = 87.190%
# Época: 4, Mini-Batches completados: 1300, Loss: 0.838, Acurácia de teste = 86.130%
# Época: 4, Mini-Batches completados: 1400, Loss: 0.846, Acurácia de teste = 86.440%
# Época: 4, Mini-Batches completados: 1500, Loss: 0.809, Acurácia de teste = 87.220%
# Época: 4, Mini-Batches completados: 1600, Loss: 0.774, Acurácia de teste = 87.060%
# Época: 4, Mini-Batches completados: 1700, Loss: 0.827, Acurácia de teste = 85.920%
# Época: 4, Mini-Batches completados: 1800, Loss: 0.846, Acurácia de teste = 87.170%
# Iniciando treino na época: 5...
# Época: 5, Mini-Batches completados: 100, Loss: 0.838, Acurácia de teste = 87.040%
# Época: 5, Mini-Batches completados: 200, Loss: 0.811, Acurácia de teste = 87.440%
# Época: 5, Mini-Batches completados: 300, Loss: 0.756, Acurácia de teste = 86.650%
# Época: 5, Mini-Batches completados: 400, Loss: 0.770, Acurácia de teste = 87.160%
# Época: 5, Mini-Batches completados: 500, Loss: 0.797, Acurácia de teste = 86.840%
# Época: 5, Mini-Batches completados: 600, Loss: 0.797, Acurácia de teste = 86.600%
# Época: 5, Mini-Batches completados: 700, Loss: 0.765, Acurácia de teste = 86.920%
# Época: 5, Mini-Batches completados: 800, Loss: 0.814, Acurácia de teste = 85.920%
# Época: 5, Mini-Batches completados: 900, Loss: 0.774, Acurácia de teste = 87.790%
# Época: 5, Mini-Batches completados: 1000, Loss: 0.763, Acurácia de teste = 87.280%
# Época: 5, Mini-Batches completados: 1100, Loss: 0.789, Acurácia de teste = 87.510%
# Época: 5, Mini-Batches completados: 1200, Loss: 0.779, Acurácia de teste = 87.530%
# Época: 5, Mini-Batches completados: 1300, Loss: 0.800, Acurácia de teste = 87.100%
# Época: 5, Mini-Batches completados: 1400, Loss: 0.780, Acurácia de teste = 87.430%
# Época: 5, Mini-Batches completados: 1500, Loss: 0.777, Acurácia de teste = 86.920%
# Época: 5, Mini-Batches completados: 1600, Loss: 0.823, Acurácia de teste = 86.460%
# Época: 5, Mini-Batches completados: 1700, Loss: 0.809, Acurácia de teste = 87.330%
# Época: 5, Mini-Batches completados: 1800, Loss: 0.752, Acurácia de teste = 87.160%
# Iniciando treino na época: 6...
# Época: 6, Mini-Batches completados: 100, Loss: 0.790, Acurácia de teste = 86.030%
# Época: 6, Mini-Batches completados: 200, Loss: 0.749, Acurácia de teste = 86.880%
# Época: 6, Mini-Batches completados: 300, Loss: 0.794, Acurácia de teste = 86.960%
# Época: 6, Mini-Batches completados: 400, Loss: 0.748, Acurácia de teste = 86.870%
# Época: 6, Mini-Batches completados: 500, Loss: 0.774, Acurácia de teste = 87.910%
# Época: 6, Mini-Batches completados: 600, Loss: 0.749, Acurácia de teste = 87.510%
# Época: 6, Mini-Batches completados: 700, Loss: 0.782, Acurácia de teste = 87.540%
# Época: 6, Mini-Batches completados: 800, Loss: 0.743, Acurácia de teste = 87.600%
# Época: 6, Mini-Batches completados: 900, Loss: 0.781, Acurácia de teste = 87.710%
# Época: 6, Mini-Batches completados: 1000, Loss: 0.702, Acurácia de teste = 88.010%
# Época: 6, Mini-Batches completados: 1100, Loss: 0.780, Acurácia de teste = 87.900%
# Época: 6, Mini-Batches completados: 1200, Loss: 0.777, Acurácia de teste = 87.900%
# Época: 6, Mini-Batches completados: 1300, Loss: 0.752, Acurácia de teste = 87.770%
# Época: 6, Mini-Batches completados: 1400, Loss: 0.756, Acurácia de teste = 87.640%
# Época: 6, Mini-Batches completados: 1500, Loss: 0.727, Acurácia de teste = 87.220%
# Época: 6, Mini-Batches completados: 1600, Loss: 0.754, Acurácia de teste = 87.510%
# Época: 6, Mini-Batches completados: 1700, Loss: 0.761, Acurácia de teste = 88.320%
# Época: 6, Mini-Batches completados: 1800, Loss: 0.746, Acurácia de teste = 86.610%
# Iniciando treino na época: 7...
# Época: 7, Mini-Batches completados: 100, Loss: 0.700, Acurácia de teste = 88.440%
# Época: 7, Mini-Batches completados: 200, Loss: 0.751, Acurácia de teste = 88.470%
# Época: 7, Mini-Batches completados: 300, Loss: 0.707, Acurácia de teste = 88.080%
# Época: 7, Mini-Batches completados: 400, Loss: 0.749, Acurácia de teste = 87.730%
# Época: 7, Mini-Batches completados: 500, Loss: 0.692, Acurácia de teste = 87.720%
# Época: 7, Mini-Batches completados: 600, Loss: 0.776, Acurácia de teste = 87.730%
# Época: 7, Mini-Batches completados: 700, Loss: 0.785, Acurácia de teste = 87.730%
# Época: 7, Mini-Batches completados: 800, Loss: 0.753, Acurácia de teste = 88.140%
# Época: 7, Mini-Batches completados: 900, Loss: 0.703, Acurácia de teste = 87.440%
# Época: 7, Mini-Batches completados: 1000, Loss: 0.763, Acurácia de teste = 88.230%
# Época: 7, Mini-Batches completados: 1100, Loss: 0.716, Acurácia de teste = 88.620%
# Época: 7, Mini-Batches completados: 1200, Loss: 0.706, Acurácia de teste = 88.640%
# Época: 7, Mini-Batches completados: 1300, Loss: 0.736, Acurácia de teste = 88.440%
# Época: 7, Mini-Batches completados: 1400, Loss: 0.732, Acurácia de teste = 87.330%
# Época: 7, Mini-Batches completados: 1500, Loss: 0.692, Acurácia de teste = 88.280%
# Época: 7, Mini-Batches completados: 1600, Loss: 0.801, Acurácia de teste = 87.470%
# Época: 7, Mini-Batches completados: 1700, Loss: 0.712, Acurácia de teste = 87.900%
# Época: 7, Mini-Batches completados: 1800, Loss: 0.713, Acurácia de teste = 87.420%
# Iniciando treino na época: 8...
# Época: 8, Mini-Batches completados: 100, Loss: 0.651, Acurácia de teste = 88.630%
# Época: 8, Mini-Batches completados: 200, Loss: 0.724, Acurácia de teste = 87.150%
# Época: 8, Mini-Batches completados: 300, Loss: 0.701, Acurácia de teste = 88.280%
# Época: 8, Mini-Batches completados: 400, Loss: 0.751, Acurácia de teste = 88.480%
# Época: 8, Mini-Batches completados: 500, Loss: 0.693, Acurácia de teste = 87.940%
# Época: 8, Mini-Batches completados: 600, Loss: 0.709, Acurácia de teste = 88.320%
# Época: 8, Mini-Batches completados: 700, Loss: 0.693, Acurácia de teste = 88.610%
# Época: 8, Mini-Batches completados: 800, Loss: 0.719, Acurácia de teste = 87.820%
# Época: 8, Mini-Batches completados: 900, Loss: 0.770, Acurácia de teste = 87.900%
# Época: 8, Mini-Batches completados: 1000, Loss: 0.706, Acurácia de teste = 87.980%
# Época: 8, Mini-Batches completados: 1100, Loss: 0.764, Acurácia de teste = 88.470%
# Época: 8, Mini-Batches completados: 1200, Loss: 0.726, Acurácia de teste = 87.960%
# Época: 8, Mini-Batches completados: 1300, Loss: 0.694, Acurácia de teste = 88.780%
# Época: 8, Mini-Batches completados: 1400, Loss: 0.692, Acurácia de teste = 88.380%
# Época: 8, Mini-Batches completados: 1500, Loss: 0.697, Acurácia de teste = 88.860%
# Época: 8, Mini-Batches completados: 1600, Loss: 0.720, Acurácia de teste = 88.670%
# Época: 8, Mini-Batches completados: 1700, Loss: 0.713, Acurácia de teste = 88.880%
# Época: 8, Mini-Batches completados: 1800, Loss: 0.725, Acurácia de teste = 88.710%
# Iniciando treino na época: 9...
# Época: 9, Mini-Batches completados: 100, Loss: 0.699, Acurácia de teste = 88.540%
# Época: 9, Mini-Batches completados: 200, Loss: 0.708, Acurácia de teste = 88.120%
# Época: 9, Mini-Batches completados: 300, Loss: 0.676, Acurácia de teste = 88.860%
# Época: 9, Mini-Batches completados: 400, Loss: 0.684, Acurácia de teste = 88.850%
# Época: 9, Mini-Batches completados: 500, Loss: 0.738, Acurácia de teste = 88.460%
# Época: 9, Mini-Batches completados: 600, Loss: 0.708, Acurácia de teste = 88.840%
# Época: 9, Mini-Batches completados: 700, Loss: 0.649, Acurácia de teste = 88.650%
# Época: 9, Mini-Batches completados: 800, Loss: 0.677, Acurácia de teste = 88.610%
# Época: 9, Mini-Batches completados: 900, Loss: 0.694, Acurácia de teste = 88.860%
# Época: 9, Mini-Batches completados: 1000, Loss: 0.684, Acurácia de teste = 88.440%
# Época: 9, Mini-Batches completados: 1100, Loss: 0.714, Acurácia de teste = 88.420%
# Época: 9, Mini-Batches completados: 1200, Loss: 0.643, Acurácia de teste = 87.510%
# Época: 9, Mini-Batches completados: 1300, Loss: 0.660, Acurácia de teste = 87.940%
# Época: 9, Mini-Batches completados: 1400, Loss: 0.671, Acurácia de teste = 87.920%
# Época: 9, Mini-Batches completados: 1500, Loss: 0.683, Acurácia de teste = 89.510%
# Época: 9, Mini-Batches completados: 1600, Loss: 0.696, Acurácia de teste = 89.150%
# Época: 9, Mini-Batches completados: 1700, Loss: 0.717, Acurácia de teste = 87.390%
# Época: 9, Mini-Batches completados: 1800, Loss: 0.699, Acurácia de teste = 88.930%
# Iniciando treino na época: 10...
# Época: 10, Mini-Batches completados: 100, Loss: 0.640, Acurácia de teste = 89.090%
# Época: 10, Mini-Batches completados: 200, Loss: 0.628, Acurácia de teste = 88.170%
# Época: 10, Mini-Batches completados: 300, Loss: 0.666, Acurácia de teste = 88.800%
# Época: 10, Mini-Batches completados: 400, Loss: 0.677, Acurácia de teste = 89.320%
# Época: 10, Mini-Batches completados: 500, Loss: 0.670, Acurácia de teste = 88.650%
# Época: 10, Mini-Batches completados: 600, Loss: 0.660, Acurácia de teste = 89.020%
# Época: 10, Mini-Batches completados: 700, Loss: 0.648, Acurácia de teste = 88.690%
# Época: 10, Mini-Batches completados: 800, Loss: 0.684, Acurácia de teste = 88.320%
# Época: 10, Mini-Batches completados: 900, Loss: 0.658, Acurácia de teste = 89.480%
# Época: 10, Mini-Batches completados: 1000, Loss: 0.659, Acurácia de teste = 89.180%
# Época: 10, Mini-Batches completados: 1100, Loss: 0.749, Acurácia de teste = 89.290%
# Época: 10, Mini-Batches completados: 1200, Loss: 0.660, Acurácia de teste = 89.120%
# Época: 10, Mini-Batches completados: 1300, Loss: 0.668, Acurácia de teste = 88.980%
# Época: 10, Mini-Batches completados: 1400, Loss: 0.674, Acurácia de teste = 89.190%
# Época: 10, Mini-Batches completados: 1500, Loss: 0.684, Acurácia de teste = 89.570%
# Época: 10, Mini-Batches completados: 1600, Loss: 0.669, Acurácia de teste = 89.170%
# Época: 10, Mini-Batches completados: 1700, Loss: 0.673, Acurácia de teste = 89.200%
# Época: 10, Mini-Batches completados: 1800, Loss: 0.669, Acurácia de teste = 88.650%
# Iniciando treino na época: 11...
# Época: 11, Mini-Batches completados: 100, Loss: 0.628, Acurácia de teste = 89.580%
# Época: 11, Mini-Batches completados: 200, Loss: 0.654, Acurácia de teste = 88.460%
# Época: 11, Mini-Batches completados: 300, Loss: 0.693, Acurácia de teste = 89.300%
# Época: 11, Mini-Batches completados: 400, Loss: 0.635, Acurácia de teste = 89.600%
# Época: 11, Mini-Batches completados: 500, Loss: 0.696, Acurácia de teste = 89.040%
# Época: 11, Mini-Batches completados: 600, Loss: 0.634, Acurácia de teste = 89.140%
# Época: 11, Mini-Batches completados: 700, Loss: 0.673, Acurácia de teste = 89.760%
# Época: 11, Mini-Batches completados: 800, Loss: 0.705, Acurácia de teste = 89.510%
# Época: 11, Mini-Batches completados: 900, Loss: 0.634, Acurácia de teste = 88.340%
# Época: 11, Mini-Batches completados: 1000, Loss: 0.648, Acurácia de teste = 89.510%
# Época: 11, Mini-Batches completados: 1100, Loss: 0.681, Acurácia de teste = 89.390%
# Época: 11, Mini-Batches completados: 1200, Loss: 0.642, Acurácia de teste = 88.990%
# Época: 11, Mini-Batches completados: 1300, Loss: 0.621, Acurácia de teste = 89.540%
# Época: 11, Mini-Batches completados: 1400, Loss: 0.642, Acurácia de teste = 89.410%
# Época: 11, Mini-Batches completados: 1500, Loss: 0.663, Acurácia de teste = 88.960%
# Época: 11, Mini-Batches completados: 1600, Loss: 0.664, Acurácia de teste = 88.540%
# Época: 11, Mini-Batches completados: 1700, Loss: 0.655, Acurácia de teste = 89.090%
# Época: 11, Mini-Batches completados: 1800, Loss: 0.606, Acurácia de teste = 89.350%
# Iniciando treino na época: 12...
# Época: 12, Mini-Batches completados: 100, Loss: 0.685, Acurácia de teste = 89.360%
# Época: 12, Mini-Batches completados: 200, Loss: 0.649, Acurácia de teste = 88.670%
# Época: 12, Mini-Batches completados: 300, Loss: 0.590, Acurácia de teste = 89.320%
# Época: 12, Mini-Batches completados: 400, Loss: 0.656, Acurácia de teste = 89.120%
# Época: 12, Mini-Batches completados: 500, Loss: 0.644, Acurácia de teste = 89.250%
# Época: 12, Mini-Batches completados: 600, Loss: 0.641, Acurácia de teste = 89.520%
# Época: 12, Mini-Batches completados: 700, Loss: 0.629, Acurácia de teste = 89.350%
# Época: 12, Mini-Batches completados: 800, Loss: 0.675, Acurácia de teste = 89.270%
# Época: 12, Mini-Batches completados: 900, Loss: 0.635, Acurácia de teste = 88.840%
# Época: 12, Mini-Batches completados: 1000, Loss: 0.738, Acurácia de teste = 89.290%
# Época: 12, Mini-Batches completados: 1100, Loss: 0.629, Acurácia de teste = 88.780%
# Época: 12, Mini-Batches completados: 1200, Loss: 0.658, Acurácia de teste = 88.960%
# Época: 12, Mini-Batches completados: 1300, Loss: 0.616, Acurácia de teste = 88.900%
# Época: 12, Mini-Batches completados: 1400, Loss: 0.651, Acurácia de teste = 89.550%
# Época: 12, Mini-Batches completados: 1500, Loss: 0.655, Acurácia de teste = 88.590%
# Época: 12, Mini-Batches completados: 1600, Loss: 0.662, Acurácia de teste = 89.250%
# Época: 12, Mini-Batches completados: 1700, Loss: 0.641, Acurácia de teste = 89.550%
# Época: 12, Mini-Batches completados: 1800, Loss: 0.627, Acurácia de teste = 89.260%
# Iniciando treino na época: 13...
# Época: 13, Mini-Batches completados: 100, Loss: 0.650, Acurácia de teste = 89.720%
# Época: 13, Mini-Batches completados: 200, Loss: 0.623, Acurácia de teste = 89.590%
# Época: 13, Mini-Batches completados: 300, Loss: 0.629, Acurácia de teste = 89.580%
# Época: 13, Mini-Batches completados: 400, Loss: 0.620, Acurácia de teste = 89.640%
# Época: 13, Mini-Batches completados: 500, Loss: 0.658, Acurácia de teste = 89.780%
# Época: 13, Mini-Batches completados: 600, Loss: 0.643, Acurácia de teste = 88.590%
# Época: 13, Mini-Batches completados: 700, Loss: 0.685, Acurácia de teste = 89.270%
# Época: 13, Mini-Batches completados: 800, Loss: 0.643, Acurácia de teste = 89.780%
# Época: 13, Mini-Batches completados: 900, Loss: 0.584, Acurácia de teste = 89.910%
# Época: 13, Mini-Batches completados: 1000, Loss: 0.601, Acurácia de teste = 89.650%
# Época: 13, Mini-Batches completados: 1100, Loss: 0.604, Acurácia de teste = 89.430%
# Época: 13, Mini-Batches completados: 1200, Loss: 0.612, Acurácia de teste = 89.650%
# Época: 13, Mini-Batches completados: 1300, Loss: 0.615, Acurácia de teste = 88.840%
# Época: 13, Mini-Batches completados: 1400, Loss: 0.677, Acurácia de teste = 89.370%
# Época: 13, Mini-Batches completados: 1500, Loss: 0.638, Acurácia de teste = 89.370%
# Época: 13, Mini-Batches completados: 1600, Loss: 0.637, Acurácia de teste = 89.330%
# Época: 13, Mini-Batches completados: 1700, Loss: 0.652, Acurácia de teste = 89.690%
# Época: 13, Mini-Batches completados: 1800, Loss: 0.670, Acurácia de teste = 89.060%
# Iniciando treino na época: 14...
# Época: 14, Mini-Batches completados: 100, Loss: 0.599, Acurácia de teste = 89.210%
# Época: 14, Mini-Batches completados: 200, Loss: 0.631, Acurácia de teste = 89.490%
# Época: 14, Mini-Batches completados: 300, Loss: 0.622, Acurácia de teste = 89.170%
# Época: 14, Mini-Batches completados: 400, Loss: 0.711, Acurácia de teste = 88.920%
# Época: 14, Mini-Batches completados: 500, Loss: 0.618, Acurácia de teste = 89.640%
# Época: 14, Mini-Batches completados: 600, Loss: 0.595, Acurácia de teste = 90.050%
# Época: 14, Mini-Batches completados: 700, Loss: 0.618, Acurácia de teste = 89.540%
# Época: 14, Mini-Batches completados: 800, Loss: 0.653, Acurácia de teste = 89.930%
# Época: 14, Mini-Batches completados: 900, Loss: 0.592, Acurácia de teste = 89.910%
# Época: 14, Mini-Batches completados: 1000, Loss: 0.625, Acurácia de teste = 89.330%
# Época: 14, Mini-Batches completados: 1100, Loss: 0.596, Acurácia de teste = 89.550%
# Época: 14, Mini-Batches completados: 1200, Loss: 0.573, Acurácia de teste = 89.600%
# Época: 14, Mini-Batches completados: 1300, Loss: 0.640, Acurácia de teste = 89.880%
# Época: 14, Mini-Batches completados: 1400, Loss: 0.587, Acurácia de teste = 88.740%
# Época: 14, Mini-Batches completados: 1500, Loss: 0.627, Acurácia de teste = 88.530%
# Época: 14, Mini-Batches completados: 1600, Loss: 0.643, Acurácia de teste = 89.140%
# Época: 14, Mini-Batches completados: 1700, Loss: 0.628, Acurácia de teste = 88.650%
# Época: 14, Mini-Batches completados: 1800, Loss: 0.620, Acurácia de teste = 89.480%
# Iniciando treino na época: 15...
# Época: 15, Mini-Batches completados: 100, Loss: 0.587, Acurácia de teste = 88.780%
# Época: 15, Mini-Batches completados: 200, Loss: 0.564, Acurácia de teste = 89.280%
# Época: 15, Mini-Batches completados: 300, Loss: 0.637, Acurácia de teste = 89.100%
# Época: 15, Mini-Batches completados: 400, Loss: 0.655, Acurácia de teste = 89.430%
# Época: 15, Mini-Batches completados: 500, Loss: 0.599, Acurácia de teste = 89.440%
# Época: 15, Mini-Batches completados: 600, Loss: 0.615, Acurácia de teste = 89.050%
# Época: 15, Mini-Batches completados: 700, Loss: 0.620, Acurácia de teste = 89.560%
# Época: 15, Mini-Batches completados: 800, Loss: 0.608, Acurácia de teste = 89.720%
# Época: 15, Mini-Batches completados: 900, Loss: 0.617, Acurácia de teste = 89.650%
# Época: 15, Mini-Batches completados: 1000, Loss: 0.593, Acurácia de teste = 89.020%
# Época: 15, Mini-Batches completados: 1100, Loss: 0.595, Acurácia de teste = 89.840%
# Época: 15, Mini-Batches completados: 1200, Loss: 0.568, Acurácia de teste = 89.350%
# Época: 15, Mini-Batches completados: 1300, Loss: 0.670, Acurácia de teste = 90.070%
# Época: 15, Mini-Batches completados: 1400, Loss: 0.593, Acurácia de teste = 89.440%
# Época: 15, Mini-Batches completados: 1500, Loss: 0.631, Acurácia de teste = 89.640%
# Época: 15, Mini-Batches completados: 1600, Loss: 0.615, Acurácia de teste = 89.930%
# Época: 15, Mini-Batches completados: 1700, Loss: 0.636, Acurácia de teste = 90.130%
# Época: 15, Mini-Batches completados: 1800, Loss: 0.636, Acurácia de teste = 89.510%
# Treino completado

# %%
correct = 0 
total = 0

with torch.no_grad():
    for data in testloader:
        images, labels = data
        # Move our data to GPU
        images = images.to(device)
        labels = labels.to(device)
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = 100 * correct / total
print(f'Acurácia da rede com 10000 imagens de teste: {accuracy:.4}%')
# Out:
# Acurácia da rede com 10000 imagens de teste: 90.06%

# %%
import matplotlib.pyplot as plt


fig, ax1 = plt.subplots()


plt.title("Accuracy & Loss vs Epoch Mini-Batches")
plt.xticks(rotation=45)

# We use twinx to create a plot a secondary y axis
ax2 = ax1.twinx()

# Create plot for loss_log and accuracy_log
ax1.plot(epoch_log, loss_log, 'g-')
ax2.plot(epoch_log, accuracy_log, 'b-')

# Set labels
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss', color='g')
ax2.set_ylabel('Test Accuracy', color='b')

plt.show()

# %% [markdown]
# # TAREFA DE CASA: APLICAR O Early Stopping
#
# https://github.com/Bjarten/early-stopping-pytorch
