# %% [markdown]
# # USANDO MARIGOLD

# %%
# !git clone https://github.com/prs-eth/Marigold.git
# %cd Marigold
# Out:
# c:\Repositorios\ModernComputerVision\EstimacaoDeProfundidade\Marigold\Marigold
# Cloning into 'Marigold'...

# %%
# !pip install -r requirements.txt
# !pip install --upgrade diffusers[torch]
# Out:
# Requirement already satisfied: accelerate>=0.22.0 in C:\Users\Gabriel\AppData\Roaming\Python\Python313\site-packages (from -r requirements.txt (line 1)) (1.10.1)
# Collecting diffusers>=0.25.0 (from -r requirements.txt (line 2))
#   Using cached diffusers-0.37.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: matplotlib in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from -r requirements.txt (line 3)) (3.10.8)
# Requirement already satisfied: scipy in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from -r requirements.txt (line 4)) (1.16.3)
# ERROR: Could not find a version that satisfies the requirement torch==2.4.1 (from versions: 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.9.1, 2.10.0, 2.11.0)
# ERROR: No matching distribution found for torch==2.4.1
# Collecting diffusers[torch]
#   Using cached diffusers-0.37.1-py3-none-any.whl.metadata (20 kB)
# Collecting importlib-metadata (from diffusers[torch])
#   Downloading importlib_metadata-9.0.0-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: filelock in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from diffusers[torch]) (3.20.1)
# Requirement already satisfied: httpx<1.0.0 in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from diffusers[torch]) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.34.0 in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from diffusers[torch]) (1.8.0)
# Requirement already satisfied: numpy in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from diffusers[torch]) (2.4.4)
# Collecting regex!=2019.12.17 (from diffusers[torch])
#   Downloading regex-2026.3.32-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: requests in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from diffusers[torch]) (2.32.5)
# Requirement already satisfied: safetensors>=0.3.1 in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from diffusers[torch]) (0.7.0)
# Requirement already satisfied: Pillow in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from diffusers[torch]) (12.0.0)
# Requirement already satisfied: torch>=1.4 in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from diffusers[torch]) (2.9.1+cu128)
# Requirement already satisfied: accelerate>=0.31.0 in C:\Users\Gabriel\AppData\Roaming\Python\Python313\site-packages (from diffusers[torch]) (1.10.1)
# Requirement already satisfied: anyio in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from httpx<1.0.0->diffusers[torch]) (4.13.0)
# Requirement already satisfied: certifi in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from httpx<1.0.0->diffusers[torch]) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from httpx<1.0.0->diffusers[torch]) (1.0.9)
# Requirement already satisfied: idna in C:\Users\Gabriel\AppData\Roaming\Python\Python313\site-packages (from httpx<1.0.0->diffusers[torch]) (3.7)
# Requirement already satisfied: h11>=0.16 in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from httpcore==1.*->httpx<1.0.0->diffusers[torch]) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (2025.12.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (1.4.2)
# Requirement already satisfied: packaging>=20.9 in C:\Users\Gabriel\AppData\Roaming\Python\Python313\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (4.67.1)
# Requirement already satisfied: typer in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (4.15.0)
# Requirement already satisfied: psutil in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from accelerate>=0.31.0->diffusers[torch]) (7.1.3)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from torch>=1.4->diffusers[torch]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from torch>=1.4->diffusers[torch]) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from torch>=1.4->diffusers[torch]) (3.1.6)
# Requirement already satisfied: setuptools in C:\Users\Gabriel\AppData\Roaming\Python\Python313\site-packages (from torch>=1.4->diffusers[torch]) (79.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from sympy>=1.13.3->torch>=1.4->diffusers[torch]) (1.3.0)
# Requirement already satisfied: colorama in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from tqdm>=4.42.1->huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (0.4.6)
# Collecting zipp>=3.20 (from importlib-metadata->diffusers[torch])
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from jinja2->torch>=1.4->diffusers[torch]) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from requests->diffusers[torch]) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from requests->diffusers[torch]) (2.6.1)
# Requirement already satisfied: click>=8.2.1 in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in C:\Users\Gabriel\AppData\Roaming\Python\Python313\site-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (14.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from typer->huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\Gabriel\AppData\Roaming\Python\Python313\site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\Gabriel\.conda\envs\dl\Lib\site-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\Gabriel\AppData\Roaming\Python\Python313\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=0.34.0->diffusers[torch]) (0.1.2)
# Downloading diffusers-0.37.1-py3-none-any.whl (5.0 MB)
#    ---------------------------------------- 0.0/5.0 MB ? eta -:--:--
#    ---------------------------------------- 5.0/5.0 MB 52.1 MB/s  0:00:00
# Downloading regex-2026.3.32-cp313-cp313-win_amd64.whl (277 kB)
# Downloading importlib_metadata-9.0.0-py3-none-any.whl (27 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Installing collected packages: zipp, regex, importlib-metadata, diffusers
#
#    ---------- ----------------------------- 1/4 [regex]
#    -------------------- ------------------- 2/4 [importlib-metadata]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ------------------------------ --------- 3/4 [diffusers]
#    ---------------------------------------- 4/4 [diffusers]
#
# Successfully installed diffusers-0.37.1 importlib-metadata-9.0.0 regex-2026.3.32 zipp-3.23.0

# %%
# %cd Marigold/
# !python script/depth/run.py --checkpoint prs-eth/marigold-depth-v1-1  --input_rgb_dir ../images --output_dir .. --fp16
# Out:
# c:\Repositorios\ModernComputerVision\EstimacaoDeProfundidade\Marigold\Marigold
# INFO:root:output dir = ..
# INFO:root:device = cuda
# INFO:root:Found 1 images
# INFO:root:Running with half precision (torch.float16), might lead to suboptimal result.
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/prs-eth/marigold-depth-v1-1 "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/prs-eth/marigold-depth-v1-1/resolve/main/model_index.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/prs-eth/marigold-depth-v1-1/9571e7123e258cf052b4e54241f17971c290e9a8/model_index.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/prs-eth/marigold-depth-v1-1/9571e7123e258cf052b4e54241f17971c290e9a8/model_index.json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/models/prs-eth/marigold-depth-v1-1/revision/main "HTTP/1.1 200 OK"
#
# Fetching 12 files:   0%|          | 0/12 [00:00<?, ?it/s]INFO:httpx:HTTP Request: HEAD https://huggingface.co/prs-eth/marigold-depth-v1-1/resolve/9571e7123e258cf052b4e54241f17971c290e9a8/scheduler/scheduler_config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/prs-eth/marigold-depth-v1-1/resolve/9571e7123e258cf052b4e54241f17971c290e9a8/text_encoder/config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/prs-eth/marigold-depth-v1-1/resolve/9571e7123e258cf052b4e54241f17971c290e9a8/tokenizer/tokenizer_config.json "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/prs-eth/marigold-depth-v1-1/resolve/9571e7123e258cf052b4e54241f17971c290e9a8/text_encoder/model.fp16.safetensors "HTTP/1.1 302 Found"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co/prs-eth/marigold-depth-v1-1/resolve/9571e7123e258cf052b4e54241f17971c290e9a8/tokenizer/merges.txt "HTTP/1.1 307 Temporary Redirect"
# INFO:httpx:HTTP Request: HEAD https://huggingface.co
json "HTTP/1.1 200 OK"
# INFO:httpx:HTTP Request: GET https://huggingface.co/api/resolve-cache/models/prs-eth/marigold-depth-v1-1/9571e7123e258cf052b4e54241f17971c290e9a8/vae%2Fconfig.json "HTTP/1.1 200 OK"
#
# Fetching 12 files:  33%|███▎      | 4/12 [00:26<01:01,  7.67s/it]
# Fetching 12 files:  83%|████████▎ | 10/12 [00:34<00:06,  3.14s/it]
# Fetching 12 files: 100%|██████████| 12/12 [00:34<00:00,  2.86s/it]
# The config attributes {'prediction_type': 'depth'} were passed to MarigoldDepthPipeline, but are not expected and will be ignored. Please verify your model_index.json configuration file.
# Keyword arguments {'prediction_type': 'depth'} are not expected by MarigoldDepthPipeline and will be ignored.
#
# Loading pipeline components...:   0%|          | 0/5 [00:00<?, ?it/s]
#
# Loading weights:   0%|          | 0/372 [00:00<?, ?it/s]
# Loading weights: 100%|██████████| 372/372 [00:00<00:00, 11592.33it/s]
# CLIPTextModel LOAD REPORT from: C:\Users\Gabriel\.cache\huggingface\hub\models--prs-eth--marigold-depth-v1-1\snapshots\9571e7123e258cf052b4e54241f17971c290e9a8\text_encoder
# Key                                | Status     |  |
# -----------------------------------+------------+--+-
# text_model.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
#
# Loading pipeline components...:  20%|██        | 1/5 [00:00<00:00,  5.86it/s]
# Loading pipeline components...:  60%|██████    | 3/5 [00:00<00:00, 11.59it/s]
# Loading pipeline components...: 100%|██████████| 5/5 [00:00<00:00, 13.50it/s]
# Loading pipeline components...: 100%|██████████| 5/5 [00:00<00:00, 12.22it/s]
# INFO:root:Loaded depth pipeline: scale_invariant=True, shift_invariant=True
# INFO:root:Inference settings: checkpoint = `prs-eth/marigold-depth-v1-1`, with denoise_steps = 4, ensemble_size = 1, processing resolution = 768, seed = None; color_map = Spectral.
#
# Depth Inference:   0%|          | 0/1 [00:00<?, ?it/s]
#
#   Inference batches:   0%|          | 0/1 [00:00<?, ?it/s]
#
#
#     Diffusion denoising:   0%|          | 0/4 [00:00<?, ?it/s]
#
#
#     Diffusion denoising:  25%|██▌       | 1/4 [00:00<00:00,  3.06it/s]
#
#
#     Diffusion denoising:  50%|█████     | 2/4 [00:00<00:00,  4.86it/s]
#
#
#     Diffusion denoising:  75%|███████▌  | 3/4 [00:00<00:00,  6.00it/s]
#
#
#     Diffusion denoising: 100%|██████████| 4/4 [00:00<00:00,  6.79it/s]
#
#
#
#
#   Inference batches: 100%|██████████| 1/1 [00:02<00:00,  2.04s/it]
#
#                                                                   c:\Repositorios\ModernComputerVision\EstimacaoDeProfundidade\Marigold\Marigold\script\depth\run.py:278: RuntimeWarning: overflow encountered in cast
#   depth_to_save = (depth_pred * 65535.0).astype(np.uint16)
# c:\Repositorios\ModernComputerVision\EstimacaoDeProfundidade\Marigold\Marigold\script\depth\run.py:278: RuntimeWarning: invalid value encountered in multiply
#   depth_to_save = (depth_pred * 65535.0).astype(np.uint16)
# c:\Repositorios\ModernComputerVision\EstimacaoDeProfundidade\Marigold\Marigold\script\depth\run.py:278: RuntimeWarning: invalid value encountered in cast
#   depth_to_save = (depth_pred * 65535.0).astype(np.uint16)
#
# Depth Inference: 100%|██████████| 1/1 [00:02<00:00,  2.38s/it]
# Depth Inference: 100%|██████████| 1/1 [00:02<00:00,  2.38s/it]
